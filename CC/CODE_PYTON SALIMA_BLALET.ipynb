# %% [markdown]
# **Importing the Necessary** **Libraries**

# %% [markdown]
# **Importing** **Data**

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("magdamonteiro/smart-cities-index-datasets")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'smart-cities-index-datasets' dataset.
# Path to dataset files: /kaggle/input/smart-cities-index-datasets

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import folium
from folium.plugins import FastMarkerCluster

# %%
import os

data = pd.read_csv(os.path.join(path, 'Smart_City_index_headers.csv'))
data
# Out:
#       Id           City      Country  Smart_Mobility   Smart_Environment  \
# 0      1           Oslo       Norway             6480               6512
# 1      2         Bergen       Norway             7097               6876
# 2      3      Amsterdam  Netherlands             7540               5558
# 3      4     Copenhagen      Denmark             7490               7920
# 4      5      Stockholm       Sweden             6122               7692
# ..   ...            ...          ...              ...                ...
# 97    98           Riga       Latvia             4152               4584
# 98    99        Beijing        China             7610               2998
# 99   100  St Petersburg       Russia             4588               2908
# 100  101        Calgary       Canada             6675               4052
# 101  102       Edmonton       Canada             5801               4499
#
#      Smart_Government   Smart_Economy   Smart_People  Smart_Living  \
# 0                 7516            4565          8618          9090
# 1                 7350            4905          8050          9090
# 2                 8528            8095          7098          7280
# 3                 8726            5580          5780          7200
# 4                 8354            4330          6743          7730
# ..                 ...             ...           ...           ...
# 97                4616            7380          3745          4330
# 98                2806            4905          5183          1980
# 99                3622            4515          5390          4100
# 100               5946            8022          6424          8657
# 101               6396            8022          6200          8141
#
#      SmartCity_Index  SmartCity_Index_relative_Edmonton
# 0               7138                                666
# 1               7296                                823
# 2               7311                                839
# 3               7171                                698
# 4               6812                                340
# ..               ...                                ...
# 97              4712                              -1760
# 98              4449                              -2023
# 99              4191                              -2281
# 100             6678                                206
# 101             6472                                  0
#
# [102 rows x 11 columns]

# %%
import kagglehub
import pandas as pd
import os

# Download the world-cities dataset
world_cities_path = kagglehub.dataset_download("juanmah/world-cities")

# Read the cities data using the downloaded path
cities = pd.read_csv(os.path.join(world_cities_path, 'worldcities.csv'))
cities
# Out:
# Using Colab cache for faster access to the 'world-cities' dataset.
#                    city        city_ascii      lat       lng  \
# 0                 Tokyo             Tokyo  35.6870  139.7495
# 1               Jakarta           Jakarta  -6.1750  106.8275
# 2                 Delhi             Delhi  28.6100   77.2300
# 3             Guangzhou         Guangzhou  23.1300  113.2600
# 4                Mumbai            Mumbai  19.0761   72.8775
# ...                 ...               ...      ...       ...
# 48054          Al Jabīn          Al Jabin  14.7040   43.5990
# 48055         Nelspruit         Nelspruit -25.4745   30.9703
# 48056          Gqeberha          Gqeberha -33.9681   25.5981
# 48057            Lupane            Lupane -18.9315   27.8070
# 48058  Charlotte Amalie  Charlotte Amalie  18.3420  -64.9331
#
#                    country iso2 iso3          admin_name  capital  population  \
# 0                    Japan   JP  JPN               Tōkyō  primary  37785000.0
# 1                Indonesia   ID  IDN             Jakarta  primary  33756000.0
# 2                    India   IN  IND               Delhi    admin  32226000.0
# 3                    China   CN  CHN           Guangdong    admin  26940000.0
# 4                    India   IN  IND         Mahārāshtra    admin  24973000.0
# ...                    ...  ...  ...                 ...      ...         ...
# 48054                Yemen   YE  YEM              Raymah    admin         NaN
# 48055         South Africa   ZA  ZAF          Mpumalanga    admin         NaN
# 48056         South Africa   ZA  ZAF        Eastern Cape      NaN         NaN
# 48057             Zimbabwe   ZW  ZWE  Matabeleland North    admin         NaN
# 48058  U.S. Virgin Islands   VI  VIR      Virgin Islands  primary         NaN
#
#                id
# 0      1392685764
# 1      1360771077
# 2      1356872604
# 3      1156237133
# 4      1356226629
# ...           ...
# 48054  1887910100
# 48055  1710114438
# 48056  1710000082
# 48057  1716206606
# 48058  1850037473
#
# [48059 rows x 11 columns]

# %%
continents = pd.read_csv('/Smart_City_index_headers.csv')
continents
# Out:
#       Id           City      Country  Smart_Mobility   Smart_Environment  \
# 0      1           Oslo       Norway             6480               6512
# 1      2         Bergen       Norway             7097               6876
# 2      3      Amsterdam  Netherlands             7540               5558
# 3      4     Copenhagen      Denmark             7490               7920
# 4      5      Stockholm       Sweden             6122               7692
# ..   ...            ...          ...              ...                ...
# 97    98           Riga       Latvia             4152               4584
# 98    99        Beijing        China             7610               2998
# 99   100  St Petersburg       Russia             4588               2908
# 100  101        Calgary       Canada             6675               4052
# 101  102       Edmonton       Canada             5801               4499
#
#      Smart_Government   Smart_Economy   Smart_People  Smart_Living  \
# 0                 7516            4565          8618          9090
# 1                 7350            4905          8050          9090
# 2                 8528            8095          7098          7280
# 3                 8726            5580          5780          7200
# 4                 8354            4330          6743          7730
# ..                 ...             ...           ...           ...
# 97                4616            7380          3745          4330
# 98                2806            4905          5183          1980
# 99                3622            4515          5390          4100
# 100               5946            8022          6424          8657
# 101               6396            8022          6200          8141
#
#      SmartCity_Index  SmartCity_Index_relative_Edmonton
# 0               7138                                666
# 1               7296                                823
# 2               7311                                839
# 3               7171                                698
# 4               6812                                340
# ..               ...                                ...
# 97              4712                              -1760
# 98              4449                              -2023
# 99              4191                              -2281
# 100             6678                                206
# 101             6472                                  0
#
# [102 rows x 11 columns]

# %% [markdown]
# **Data** **Preprocessing**

# %%
# Check null values by columns
data.isnull().sum()
# Out:
# Id                                   0
# City                                 0
# Country                              0
# Smart_Mobility                       0
# Smart_Environment                    0
# Smart_Government                     0
# Smart_Economy                        0
# Smart_People                         0
# Smart_Living                         0
# SmartCity_Index                      0
# SmartCity_Index_relative_Edmonton    0
# dtype: int64

# %%
# Check what columns do I have
data.columns
# Out:
# Index(['Id', 'City', 'Country', 'Smart_Mobility ', 'Smart_Environment',
#        'Smart_Government ', 'Smart_Economy ', 'Smart_People', 'Smart_Living',
#        'SmartCity_Index', 'SmartCity_Index_relative_Edmonton'],
#       dtype='object')

# %%
# There are some spaces of each column head
# Therefore, we need to remove those
dict_rename = {'Smart_Mobility ': 'Smart_Mobility',
          'Smart_Government ': 'Smart_Government',
          'Smart_Economy ': 'Smart_Economy'
          }
dict_rename
# Out:
# {'Smart_Mobility ': 'Smart_Mobility',
#  'Smart_Government ': 'Smart_Government',
#  'Smart_Economy ': 'Smart_Economy'}

# %%
data.rename(columns=dict_rename, inplace=True)
data
# Out:
#       Id           City      Country  Smart_Mobility  Smart_Environment  \
# 0      1           Oslo       Norway            6480               6512
# 1      2         Bergen       Norway            7097               6876
# 2      3      Amsterdam  Netherlands            7540               5558
# 3      4     Copenhagen      Denmark            7490               7920
# 4      5      Stockholm       Sweden            6122               7692
# ..   ...            ...          ...             ...                ...
# 97    98           Riga       Latvia            4152               4584
# 98    99        Beijing        China            7610               2998
# 99   100  St Petersburg       Russia            4588               2908
# 100  101        Calgary       Canada            6675               4052
# 101  102       Edmonton       Canada            5801               4499
#
#      Smart_Government  Smart_Economy  Smart_People  Smart_Living  \
# 0                7516           4565          8618          9090
# 1                7350           4905          8050          9090
# 2                8528           8095          7098          7280
# 3                8726           5580          5780          7200
# 4                8354           4330          6743          7730
# ..                ...            ...           ...           ...
# 97               4616           7380          3745          4330
# 98               2806           4905          5183          1980
# 99               3622           4515          5390          4100
# 100              5946           8022          6424          8657
# 101              6396           8022          6200          8141
#
#      SmartCity_Index  SmartCity_Index_relative_Edmonton
# 0               7138                                666
# 1               7296                                823
# 2               7311                                839
# 3               7171                                698
# 4               6812                                340
# ..               ...                                ...
# 97              4712                              -1760
# 98              4449                              -2023
# 99              4191                              -2281
# 100             6678                                206
# 101             6472                                  0
#
# [102 rows x 11 columns]

# %%
# Check null values by columns
data.isnull().sum()
# Out:
# Id                                   0
# City                                 0
# Country                              0
# Smart_Mobility                       0
# Smart_Environment                    0
# Smart_Government                     0
# Smart_Economy                        0
# Smart_People                         0
# Smart_Living                         0
# SmartCity_Index                      0
# SmartCity_Index_relative_Edmonton    0
# dtype: int64

# %%
# The 'country_and_continent.csv' file could not be loaded due to a FileNotFoundError.
# An attempt to download the dataset from Kaggle resulted in a 403 Client Error (permission denied).
# Therefore, this line has been commented out to prevent further errors.
# continents = pd.read_csv('../input/country-and-continent/country_and_continent.csv')

# %%
# Remove rows which has nulll values
cities.dropna(axis=0, inplace=True)
cities.reset_index(drop=True, inplace=True)
cities
# Out:
#                city    city_ascii      lat       lng          country iso2  \
# 0             Tokyo         Tokyo  35.6870  139.7495            Japan   JP
# 1           Jakarta       Jakarta  -6.1750  106.8275        Indonesia   ID
# 2             Delhi         Delhi  28.6100   77.2300            India   IN
# 3         Guangzhou     Guangzhou  23.1300  113.2600            China   CN
# 4            Mumbai        Mumbai  19.0761   72.8775            India   IN
# ...             ...           ...      ...       ...              ...  ...
# 14860       Samamea       Samamea -13.9333 -171.5333            Samoa   WS
# 14861     Bogovinje     Bogovinje  41.9233   20.9133  North Macedonia   MK
# 14862       Vransko       Vransko  46.1720   14.8217         Slovenia   SI
# 14863  Gaigirgordub  Gaigirgordub   9.5583  -78.9483           Panama   PA
# 14864        Kostel        Kostel  45.5088   14.9100         Slovenia   SI
#
#       iso3     admin_name  capital  population          id
# 0      JPN          Tōkyō  primary  37785000.0  1392685764
# 1      IDN        Jakarta  primary  33756000.0  1360771077
# 2      IND          Delhi    admin  32226000.0  1356872604
# 3      CHN      Guangdong    admin  26940000.0  1156237133
# 4      IND    Mahārāshtra    admin  24973000.0  1356226629
# ...    ...            ...      ...         ...         ...
# 14860  WSM  Va‘a-o-Fonoti    admin        45.0  1882468874
# 14861  MKD      Bogovinje    admin        25.0  1807279534
# 14862  SVN        Vransko    admin        11.0  1705616966
# 14863  PAN      Guna Yala    admin        10.0  1591425685
# 14864  SVN         Kostel    admin        10.0  1705541759
#
# [14865 rows x 11 columns]

# %%
# Re-Check null values by columns
cities.isnull().sum()
# Out:
# city          0
# city_ascii    0
# lat           0
# lng           0
# country       0
# iso2          0
# iso3          0
# admin_name    0
# capital       0
# population    0
# id            0
# dtype: int64

# %%
continents.isnull().sum()
# Out:
# Id                                   0
# City                                 0
# Country                              0
# Smart_Mobility                       0
# Smart_Environment                    0
# Smart_Government                     0
# Smart_Economy                        0
# Smart_People                         0
# Smart_Living                         0
# SmartCity_Index                      0
# SmartCity_Index_relative_Edmonton    0
# dtype: int64

# %%
# Remove rows which has nulll values
cities.dropna(axis=0, inplace=True)
cities.reset_index(drop=True, inplace=True)
cities
# Out:
#                city    city_ascii      lat       lng          country iso2  \
# 0             Tokyo         Tokyo  35.6870  139.7495            Japan   JP
# 1           Jakarta       Jakarta  -6.1750  106.8275        Indonesia   ID
# 2             Delhi         Delhi  28.6100   77.2300            India   IN
# 3         Guangzhou     Guangzhou  23.1300  113.2600            China   CN
# 4            Mumbai        Mumbai  19.0761   72.8775            India   IN
# ...             ...           ...      ...       ...              ...  ...
# 14860       Samamea       Samamea -13.9333 -171.5333            Samoa   WS
# 14861     Bogovinje     Bogovinje  41.9233   20.9133  North Macedonia   MK
# 14862       Vransko       Vransko  46.1720   14.8217         Slovenia   SI
# 14863  Gaigirgordub  Gaigirgordub   9.5583  -78.9483           Panama   PA
# 14864        Kostel        Kostel  45.5088   14.9100         Slovenia   SI
#
#       iso3     admin_name  capital  population          id
# 0      JPN          Tōkyō  primary  37785000.0  1392685764
# 1      IDN        Jakarta  primary  33756000.0  1360771077
# 2      IND          Delhi    admin  32226000.0  1356872604
# 3      CHN      Guangdong    admin  26940000.0  1156237133
# 4      IND    Mahārāshtra    admin  24973000.0  1356226629
# ...    ...            ...      ...         ...         ...
# 14860  WSM  Va‘a-o-Fonoti    admin        45.0  1882468874
# 14861  MKD      Bogovinje    admin        25.0  1807279534
# 14862  SVN        Vransko    admin        11.0  1705616966
# 14863  PAN      Guna Yala    admin        10.0  1591425685
# 14864  SVN         Kostel    admin        10.0  1705541759
#
# [14865 rows x 11 columns]

# %%
# Re-Check null values by columns
cities.isnull().sum()
# Out:
# city          0
# city_ascii    0
# lat           0
# lng           0
# country       0
# iso2          0
# iso3          0
# admin_name    0
# capital       0
# population    0
# id            0
# dtype: int64

# %% [markdown]
# **continents**

# %%
continents.isnull().sum()
# Out:
# Id                                   0
# City                                 0
# Country                              0
# Smart_Mobility                       0
# Smart_Environment                    0
# Smart_Government                     0
# Smart_Economy                        0
# Smart_People                         0
# Smart_Living                         0
# SmartCity_Index                      0
# SmartCity_Index_relative_Edmonton    0
# dtype: int64

# %%
# Remove rows which has nulll values
continents.dropna(axis=0, inplace=True)
continents.reset_index(drop=True, inplace=True)
continents
# Out:
#       Id           City      Country  Smart_Mobility   Smart_Environment  \
# 0      1           Oslo       Norway             6480               6512
# 1      2         Bergen       Norway             7097               6876
# 2      3      Amsterdam  Netherlands             7540               5558
# 3      4     Copenhagen      Denmark             7490               7920
# 4      5      Stockholm       Sweden             6122               7692
# ..   ...            ...          ...              ...                ...
# 97    98           Riga       Latvia             4152               4584
# 98    99        Beijing        China             7610               2998
# 99   100  St Petersburg       Russia             4588               2908
# 100  101        Calgary       Canada             6675               4052
# 101  102       Edmonton       Canada             5801               4499
#
#      Smart_Government   Smart_Economy   Smart_People  Smart_Living  \
# 0                 7516            4565          8618          9090
# 1                 7350            4905          8050          9090
# 2                 8528            8095          7098          7280
# 3                 8726            5580          5780          7200
# 4                 8354            4330          6743          7730
# ..                 ...             ...           ...           ...
# 97                4616            7380          3745          4330
# 98                2806            4905          5183          1980
# 99                3622            4515          5390          4100
# 100               5946            8022          6424          8657
# 101               6396            8022          6200          8141
#
#      SmartCity_Index  SmartCity_Index_relative_Edmonton
# 0               7138                                666
# 1               7296                                823
# 2               7311                                839
# 3               7171                                698
# 4               6812                                340
# ..               ...                                ...
# 97              4712                              -1760
# 98              4449                              -2023
# 99              4191                              -2281
# 100             6678                                206
# 101             6472                                  0
#
# [102 rows x 11 columns]

# %% [markdown]
# **Data** **Preparation**

# %%
# Merge two DataFrames
cities_continents = pd.merge(cities, continents, left_on='country', right_on='Country')
cities_continents
# Out:
#             city city_ascii      lat       lng   country iso2 iso3  \
# 0          Tokyo      Tokyo  35.6870  139.7495     Japan   JP  JPN
# 1          Tokyo      Tokyo  35.6870  139.7495     Japan   JP  JPN
# 2      Guangzhou  Guangzhou  23.1300  113.2600     China   CN  CHN
# 3      Guangzhou  Guangzhou  23.1300  113.2600     China   CN  CHN
# 4      Guangzhou  Guangzhou  23.1300  113.2600     China   CN  CHN
# ...          ...        ...      ...       ...       ...  ...  ...
# 13861   Osilnica   Osilnica  45.5289   14.6983  Slovenia   SI  SVN
# 13862    Sovetsk    Sovetsk  57.5833   48.9833    Russia   RU  RUS
# 13863    Sovetsk    Sovetsk  57.5833   48.9833    Russia   RU  RUS
# 13864    Vransko    Vransko  46.1720   14.8217  Slovenia   SI  SVN
# 13865     Kostel     Kostel  45.5088   14.9100  Slovenia   SI  SVN
#
#                admin_name  capital  population  ...           City   Country  \
# 0                   Tōkyō  primary  37785000.0  ...          Tokyo     Japan
# 1                   Tōkyō  primary  37785000.0  ...          Osaka     Japan
# 2               Guangdong    admin  26940000.0  ...      Hong Kong     China
# 3               Guangdong    admin  26940000.0  ...       Shanghai     China
# 4               Guangdong    admin  26940000.0  ...        Beijing     China
# ...                   ...      ...         ...  ...            ...       ...
# 13861            Osilnica    admin        76.0  ...      Ljubljana  Slovenia
# 13862  Kirovskaya Oblast’    minor        63.0  ...         Moscow    Russia
# 13863  Kirovskaya Oblast’    minor        63.0  ...  St Petersburg    Russia
# 13864             Vransko    admin        11.0  ...      Ljubljana  Slovenia
# 13865              Kostel    admin        10.0  ...      Ljubljana  Slovenia
#
#       Smart_Mobility  Smart_Environment  Smart_Government   Smart_Economy   \
# 0                7787              4516               5476            1800
# 1                7233              4758               5732            2105
# 2                6143              3340               4984            4780
# 3                6870              2936               3842            4430
# 4                7610              2998               2806            4905
# ...               ...               ...                ...             ...
# 13861            4540              4502               5490            7190
# 13862            5015              2772               5078            5030
# 13863            4588              2908               3622            4515
# 13864            4540              4502               5490            7190
# 13865            4540              4502               5490            7190
#
#        Smart_People  Smart_Living  SmartCity_Index  \
# 0              4158          9320             5914
# 1              3403          9320             5795
# 2              4385          1980             4313
# 3              4423          1980             4228
# 4              5183          1980             4449
# ...             ...           ...              ...
# 13861          5503          4180             5089
# 13862          4143          4100             4365
# 13863          5390          4100             4191
# 13864          5503          4180             5089
# 13865          5503          4180             5089
#
#        SmartCity_Index_relative_Edmonton
# 0                                   -558
# 1                                   -678
# 2                                  -2160
# 3                                  -2244
# 4                                  -2023
# ...                                  ...
# 13861                              -1384
# 13862                              -2108
# 13863                              -2281
# 13864                              -1384
# 13865                              -1384
#
# [13866 rows x 22 columns]

# %%
# Manual mapping of countries to continents
continent_mapping = {
    'Norway': 'Europe',
    'Netherlands': 'Europe',
    'Denmark': 'Europe',
    'Sweden': 'Europe',
    'Finland': 'Europe',
    'Switzerland': 'Europe',
    'Germany': 'Europe',
    'United Kingdom': 'Europe',
    'Ireland': 'Europe',
    'France': 'Europe',
    'Belgium': 'Europe',
    'Austria': 'Europe',
    'Luxembourg': 'Europe',
    'Spain': 'Europe',
    'Portugal': 'Europe',
    'Italy': 'Europe',
    'Estonia': 'Europe',
    'Poland': 'Europe',
    'Hungary': 'Europe',
    'Lithuania': 'Europe',
    'Latvia': 'Europe',
    'Slovenia': 'Europe',
    'Russia': 'Europe/Asia',
    'Canada': 'North America',
    'United States': 'North America',
    'Australia': 'Oceania',
    'New Zealand': 'Oceania',
    'Japan': 'Asia',
    'South Korea': 'Asia',
    'Singapore': 'Asia',
    'United Arab Emirates': 'Asia',
    'China': 'Asia',
    'Taiwan': 'Asia',
    'Hong Kong': 'Asia',
    'India': 'Asia',
    'Israel': 'Asia',
    'Malaysia': 'Asia',
    'Thailand': 'Asia',
    'Philippines': 'Asia',
    'Indonesia': 'Asia',
    'Saudi Arabia': 'Asia',
    'Turkey': 'Europe/Asia',
    'Colombia': 'South America',
    'Chile': 'South America',
    'Argentina': 'South America',
    'Brazil': 'South America',
    'Mexico': 'North America',
    'South Africa': 'Africa',
    'Kenya': 'Africa',
    'Rwanda': 'Africa',
    'Egypt': 'Africa'
}

# Create a DataFrame from the mapping
continents_df = pd.DataFrame(list(continent_mapping.items()), columns=['Country', 'Continent_Name'])

# Replace the existing 'continents' DataFrame with this new one
continents = continents_df

print("Updated 'continents' DataFrame with country-to-continent mapping:")
print(continents.head())
# Out:
# Updated 'continents' DataFrame with country-to-continent mapping:
#        Country Continent_Name
# 0       Norway         Europe
# 1  Netherlands         Europe
# 2      Denmark         Europe
# 3       Sweden         Europe
# 4      Finland         Europe

# %%
# Check Null values
cities_continents.isnull().sum()
# Out:
# city                                 0
# city_ascii                           0
# lat                                  0
# lng                                  0
# country                              0
# iso2                                 0
# iso3                                 0
# admin_name                           0
# capital                              0
# population                           0
# id                                   0
# Id                                   0
# City                                 0
# Country                              0
# Smart_Mobility                       0
# Smart_Environment                    0
# Smart_Government                     0
# Smart_Economy                        0
# Smart_People                         0
# Smart_Living                         0
# SmartCity_Index                      0
# SmartCity_Index_relative_Edmonton    0
# dtype: int64

# %%
# Merge two DataFrames
cities_continents = pd.merge(cities, continents, left_on='country', right_on='Country')
cities_continents
# Out:
#             city city_ascii      lat       lng    country iso2 iso3  \
# 0          Tokyo      Tokyo  35.6870  139.7495      Japan   JP  JPN
# 1        Jakarta    Jakarta  -6.1750  106.8275  Indonesia   ID  IDN
# 2          Delhi      Delhi  28.6100   77.2300      India   IN  IND
# 3      Guangzhou  Guangzhou  23.1300  113.2600      China   CN  CHN
# 4         Mumbai     Mumbai  19.0761   72.8775      India   IN  IND
# ...          ...        ...      ...       ...        ...  ...  ...
# 10202   Osilnica   Osilnica  45.5289   14.6983   Slovenia   SI  SVN
# 10203    Sovetsk    Sovetsk  57.5833   48.9833     Russia   RU  RUS
# 10204   Pagėgiai   Pagegiai  55.1333   21.9167  Lithuania   LT  LTU
# 10205    Vransko    Vransko  46.1720   14.8217   Slovenia   SI  SVN
# 10206     Kostel     Kostel  45.5088   14.9100   Slovenia   SI  SVN
#
#                admin_name  capital  population          id    Country  \
# 0                   Tōkyō  primary  37785000.0  1392685764      Japan
# 1                 Jakarta  primary  33756000.0  1360771077  Indonesia
# 2                   Delhi    admin  32226000.0  1356872604      India
# 3               Guangdong    admin  26940000.0  1156237133      China
# 4             Mahārāshtra    admin  24973000.0  1356226629      India
# ...                   ...      ...         ...         ...        ...
# 10202            Osilnica    admin        76.0  1705839708   Slovenia
# 10203  Kirovskaya Oblast’    minor        63.0  1643054411     Russia
# 10204            Pagégiai    admin        57.0  1440724133  Lithuania
# 10205             Vransko    admin        11.0  1705616966   Slovenia
# 10206              Kostel    admin        10.0  1705541759   Slovenia
#
#       Continent_Name
# 0               Asia
# 1               Asia
# 2               Asia
# 3               Asia
# 4               Asia
# ...              ...
# 10202         Europe
# 10203    Europe/Asia
# 10204         Europe
# 10205         Europe
# 10206         Europe
#
# [10207 rows x 13 columns]

# %%
# Define variable in order to filter 'cities_continents'
# continent = input('>>> Input Continent Name: ')
# Once uploading on Kaggle, the 'input' doesn't working
# Thus, I defined 'continent' variable as 'Asia' :)
continent = 'Asia'

# %%
# We have too muich data on 'cities_continents'
# So, we will figure out continents by continents
cities_continents_filtered = cities_continents[cities_continents['Continent_Name'] == continent]
cities_continents_filtered
# Out:
#                city    city_ascii      lat       lng    country iso2 iso3  \
# 0             Tokyo         Tokyo  35.6870  139.7495      Japan   JP  JPN
# 1           Jakarta       Jakarta  -6.1750  106.8275  Indonesia   ID  IDN
# 2             Delhi         Delhi  28.6100   77.2300      India   IN  IND
# 3         Guangzhou     Guangzhou  23.1300  113.2600      China   CN  CHN
# 4            Mumbai        Mumbai  19.0761   72.8775      India   IN  IND
# ...             ...           ...      ...       ...        ...  ...  ...
# 9882   Mae Hong Son  Mae Hong Son  19.3011   97.9700   Thailand   TH  THA
# 9943       Jinzhong      Jinzhong  26.3504  103.4167      China   CN  CHN
# 9996     Nonthaburi    Nonthaburi  13.8667  100.5167   Thailand   TH  THA
# 10055        Sofifi        Sofifi   0.7244  127.5806  Indonesia   ID  IDN
# 10137         Linxi         Linxi  43.5171  118.0333      China   CN  CHN
#
#            admin_name  capital  population          id    Country  \
# 0               Tōkyō  primary  37785000.0  1392685764      Japan
# 1             Jakarta  primary  33756000.0  1360771077  Indonesia
# 2               Delhi    admin  32226000.0  1356872604      India
# 3           Guangdong    admin  26940000.0  1156237133      China
# 4         Mahārāshtra    admin  24973000.0  1356226629      India
# ...               ...      ...         ...         ...        ...
# 9882     Mae Hong Son    admin      7066.0  1764090874   Thailand
# 9943           Yunnan    minor      5170.0  1156252749      China
# 9996       Nonthaburi    admin      3418.0  1764667935   Thailand
# 10055    Maluku Utara    admin      2000.0  1360431437  Indonesia
# 10137  Inner Mongolia    minor       679.0  1156608652      China
#
#       Continent_Name
# 0               Asia
# 1               Asia
# 2               Asia
# 3               Asia
# 4               Asia
# ...              ...
# 9882            Asia
# 9943            Asia
# 9996            Asia
# 10055           Asia
# 10137           Asia
#
# [1380 rows x 13 columns]

# %%
# Prepare DataFrame for Visualization
cities_continents_visualization = pd.merge(data, cities_continents_filtered, left_on='City', right_on='city_ascii')
cities_continents_visualization.drop(['Id', 'SmartCity_Index', 'SmartCity_Index_relative_Edmonton', 'city_ascii', 'country'], axis=1, inplace=True)
cities_continents_visualization
# Out:
#         City             Country_x  Smart_Mobility  Smart_Environment  \
# 0     Taipei                Taiwan            4978               4366
# 1      Tokyo                 Japan            7787               4516
# 2      Osaka                 Japan            7233               4758
# 3  Abu Dhabi  United Arab Emirates            7302               2108
# 4      Dubai  United Arab Emirates            7280               1850
# 5   Shanghai                 China            6870               2936
# 6    Beijing                 China            7610               2998
#
#    Smart_Government  Smart_Economy  Smart_People  Smart_Living       city  \
# 0              7044           3310          7858          7350     Taipei
# 1              5476           1800          4158          9320      Tokyo
# 2              5732           2105          3403          9320      Ōsaka
# 3              5948           3325          5933          2130  Abu Dhabi
# 4              4142           2395          7125          2130      Dubai
# 5              3842           4430          4423          1980   Shanghai
# 6              2806           4905          5183          1980    Beijing
#
#        lat       lng iso2 iso3 admin_name  capital  population          id  \
# 0  25.0375  121.5625   TW  TWN     Taipei  primary   2494813.0  1158881289
# 1  35.6870  139.7495   JP  JPN      Tōkyō  primary  37785000.0  1392685764
# 2  34.6939  135.5022   JP  JPN      Ōsaka    admin  15126000.0  1392419823
# 3  24.4667   54.3667   AE  ARE  Abū Z̧aby  primary   1483000.0  1784176710
# 4  25.2631   55.2972   AE  ARE     Dubayy    admin   3331420.0  1784736618
# 5  31.2286  121.4747   CN  CHN   Shanghai    admin  24073000.0  1156073548
# 6  39.9067  116.3975   CN  CHN    Beijing  primary  18522000.0  1156228865
#
#               Country_y Continent_Name
# 0                Taiwan           Asia
# 1                 Japan           Asia
# 2                 Japan           Asia
# 3  United Arab Emirates           Asia
# 4  United Arab Emirates           Asia
# 5                 China           Asia
# 6                 China           Asia

# %%
# Insert "Smart_Total" column in order to compare total index

for i in range(2, 8):
    cities_continents_visualization['Smart_Total'] = np.empty(shape=(len(cities_continents_visualization.index), 1))
    cities_continents_visualization['Smart_Total'] += cities_continents_visualization.iloc[:, i]
    cities_continents_visualization['Smart_Total']

cities_continents_visualization
# Out:
#         City             Country_x  Smart_Mobility  Smart_Environment  \
# 0     Taipei                Taiwan            4978               4366
# 1      Tokyo                 Japan            7787               4516
# 2      Osaka                 Japan            7233               4758
# 3  Abu Dhabi  United Arab Emirates            7302               2108
# 4      Dubai  United Arab Emirates            7280               1850
# 5   Shanghai                 China            6870               2936
# 6    Beijing                 China            7610               2998
#
#    Smart_Government  Smart_Economy  Smart_People  Smart_Living       city  \
# 0              7044           3310          7858          7350     Taipei
# 1              5476           1800          4158          9320      Tokyo
# 2              5732           2105          3403          9320      Ōsaka
# 3              5948           3325          5933          2130  Abu Dhabi
# 4              4142           2395          7125          2130      Dubai
# 5              3842           4430          4423          1980   Shanghai
# 6              2806           4905          5183          1980    Beijing
#
#        lat       lng iso2 iso3 admin_name  capital  population          id  \
# 0  25.0375  121.5625   TW  TWN     Taipei  primary   2494813.0  1158881289
# 1  35.6870  139.7495   JP  JPN      Tōkyō  primary  37785000.0  1392685764
# 2  34.6939  135.5022   JP  JPN      Ōsaka    admin  15126000.0  1392419823
# 3  24.4667   54.3667   AE  ARE  Abū Z̧aby  primary   1483000.0  1784176710
# 4  25.2631   55.2972   AE  ARE     Dubayy    admin   3331420.0  1784736618
# 5  31.2286  121.4747   CN  CHN   Shanghai    admin  24073000.0  1156073548
# 6  39.9067  116.3975   CN  CHN    Beijing  primary  18522000.0  1156228865
#
#               Country_y Continent_Name  Smart_Total
# 0                Taiwan           Asia      34906.0
# 1                 Japan           Asia      33057.0
# 2                 Japan           Asia      32551.0
# 3  United Arab Emirates           Asia      26746.0
# 4  United Arab Emirates           Asia      24922.0
# 5                 China           Asia      24481.0
# 6                 China           Asia      25482.0

# %%
# Relocation of columns
cities_continents_visualization = cities_continents_visualization[['City', 'Country_x', 'Smart_Mobility', 'Smart_Environment', 'Smart_Government', 'Smart_Economy', 'Smart_People', 'Smart_Living', 'Smart_Total', 'lat', 'lng', 'iso2', 'iso3', 'Continent_Name']]
cities_continents_visualization
# Out:
#         City             Country_x  Smart_Mobility  Smart_Environment  \
# 0     Taipei                Taiwan            4978               4366
# 1      Tokyo                 Japan            7787               4516
# 2      Osaka                 Japan            7233               4758
# 3  Abu Dhabi  United Arab Emirates            7302               2108
# 4      Dubai  United Arab Emirates            7280               1850
# 5   Shanghai                 China            6870               2936
# 6    Beijing                 China            7610               2998
#
#    Smart_Government  Smart_Economy  Smart_People  Smart_Living  Smart_Total  \
# 0              7044           3310          7858          7350      34906.0
# 1              5476           1800          4158          9320      33057.0
# 2              5732           2105          3403          9320      32551.0
# 3              5948           3325          5933          2130      26746.0
# 4              4142           2395          7125          2130      24922.0
# 5              3842           4430          4423          1980      24481.0
# 6              2806           4905          5183          1980      25482.0
#
#        lat       lng iso2 iso3 Continent_Name
# 0  25.0375  121.5625   TW  TWN           Asia
# 1  35.6870  139.7495   JP  JPN           Asia
# 2  34.6939  135.5022   JP  JPN           Asia
# 3  24.4667   54.3667   AE  ARE           Asia
# 4  25.2631   55.2972   AE  ARE           Asia
# 5  31.2286  121.4747   CN  CHN           Asia
# 6  39.9067  116.3975   CN  CHN           Asia

# %%
# Display Single Plot
sns.barplot(data=cities_continents_visualization, x='City', y='Smart_Total', palette='pastel', hue='City', legend=False)
plt.xticks(rotation=90)
plt.title('City - Total')

plt.show()

# %%
# Display Subplots
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(nrows=2, ncols=3)
fig.suptitle('Smart Index Bar Plot by Each City', fontsize=30)
fig.set_size_inches(18, 18)

sns.barplot(data=cities_continents_visualization, x="City", y="Smart_Mobility", palette='pastel', ax=ax1)
sns.barplot(data=cities_continents_visualization, x="City", y="Smart_Environment", palette='pastel', ax=ax2)
sns.barplot(data=cities_continents_visualization, x="City", y="Smart_Government", palette='pastel', ax=ax3)
sns.barplot(data=cities_continents_visualization, x="City", y="Smart_Economy", palette='pastel', ax=ax4)
sns.barplot(data=cities_continents_visualization, x="City", y="Smart_People", palette='pastel', ax=ax5)
sns.barplot(data=cities_continents_visualization, x="City", y="Smart_Living", palette='pastel', ax=ax6)
# Out:
# /tmp/ipython-input-899972909.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=cities_continents_visualization, x="City", y="Smart_Mobility", palette='pastel', ax=ax1)
# /tmp/ipython-input-899972909.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=cities_continents_visualization, x="City", y="Smart_Environment", palette='pastel', ax=ax2)
# /tmp/ipython-input-899972909.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=cities_continents_visualization, x="City", y="Smart_Government", palette='pastel', ax=ax3)
# /tmp/ipython-input-899972909.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=cities_continents_visualization, x="City", y="Smart_Economy", palette='pastel', ax=ax4)
# /tmp/ipython-input-899972909.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=cities_continents_visualization, x="City", y="Smart_People", palette='pastel', ax=ax5)
# /tmp/ipython-input-899972909.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=cities_continents_visualization, x="City", y="Smart_Living", palette='pastel', ax=ax6)
# <Axes: xlabel='City', ylabel='Smart_Living'>

# %%
cities_continents_visualization_copy = cities_continents_visualization.copy()
cities_continents_heatmap = cities_continents_visualization_copy.drop(['Country_x', 'Smart_Total', 'lat', 'lng', 'iso2', 'iso3'], axis=1)
cities_continents_heatmap
# Out:
#         City  Smart_Mobility  Smart_Environment  Smart_Government  \
# 0     Taipei            4978               4366              7044
# 1      Tokyo            7787               4516              5476
# 2      Osaka            7233               4758              5732
# 3  Abu Dhabi            7302               2108              5948
# 4      Dubai            7280               1850              4142
# 5   Shanghai            6870               2936              3842
# 6    Beijing            7610               2998              2806
#
#    Smart_Economy  Smart_People  Smart_Living Continent_Name
# 0           3310          7858          7350           Asia
# 1           1800          4158          9320           Asia
# 2           2105          3403          9320           Asia
# 3           3325          5933          2130           Asia
# 4           2395          7125          2130           Asia
# 5           4430          4423          1980           Asia
# 6           4905          5183          1980           Asia

# %%
# Check null values by columns
cities.isnull().sum()
# Out:
# city          0
# city_ascii    0
# lat           0
# lng           0
# country       0
# iso2          0
# iso3          0
# admin_name    0
# capital       0
# population    0
# id            0
# dtype: int64

# %%
print("First 5 rows of cities_continents_heatmap:")
display(cities_continents_heatmap.head())
# Out:
# First 5 rows of cities_continents_heatmap:
#         City  Smart_Mobility  Smart_Environment  Smart_Government  \
# 0     Taipei            4978               4366              7044
# 1      Tokyo            7787               4516              5476
# 2      Osaka            7233               4758              5732
# 3  Abu Dhabi            7302               2108              5948
# 4      Dubai            7280               1850              4142
#
#    Smart_Economy  Smart_People  Smart_Living Continent_Name
# 0           3310          7858          7350           Asia
# 1           1800          4158          9320           Asia
# 2           2105          3403          9320           Asia
# 3           3325          5933          2130           Asia
# 4           2395          7125          2130           Asia

# %%
print("Information about cities_continents_heatmap:")
cities_continents_heatmap.info()
# Out:
# Information about cities_continents_heatmap:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   City               7 non-null      object
#  1   Smart_Mobility     7 non-null      int64
#  2   Smart_Environment  7 non-null      int64
#  3   Smart_Government   7 non-null      int64
#  4   Smart_Economy      7 non-null      int64
#  5   Smart_People       7 non-null      int64
#  6   Smart_Living       7 non-null      int64
#  7   Continent_Name     7 non-null      object
# dtypes: int64(6), object(2)
# memory usage: 580.0+ bytes

# %%
# Heatmap
plt.figure(figsize=(10, 10))
sns.heatmap(data=cities_continents_pivot, annot=True, annot_kws={"size":10},linewidths=.5, cmap="YlGnBu", fmt="")
plt.show()

# %%
# Display a map centered in Asia
map = folium.Map(location=(29, 100), zoom_start=3)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1df29acbc356ad30b0e54eab44f32f0a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1df29acbc356ad30b0e54eab44f32f0a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1df29acbc356ad30b0e54eab44f32f0a = L.map(
#                 &quot;map_1df29acbc356ad30b0e54eab44f32f0a&quot;,
#                 {
#                     center: [29.0, 100.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 3,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0683d1805dacf1d6c12e0856c790ff43 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0683d1805dacf1d6c12e0856c790ff43.addTo(map_1df29acbc356ad30b0e54eab44f32f0a);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
cities_continents_visualization_copy
# Out:
#         City             Country_x  Smart_Mobility  Smart_Environment  \
# 0     Taipei                Taiwan            4978               4366
# 1      Tokyo                 Japan            7787               4516
# 2      Osaka                 Japan            7233               4758
# 3  Abu Dhabi  United Arab Emirates            7302               2108
# 4      Dubai  United Arab Emirates            7280               1850
# 5   Shanghai                 China            6870               2936
# 6    Beijing                 China            7610               2998
#
#    Smart_Government  Smart_Economy  Smart_People  Smart_Living  Smart_Total  \
# 0              7044           3310          7858          7350      34906.0
# 1              5476           1800          4158          9320      33057.0
# 2              5732           2105          3403          9320      32551.0
# 3              5948           3325          5933          2130      26746.0
# 4              4142           2395          7125          2130      24922.0
# 5              3842           4430          4423          1980      24481.0
# 6              2806           4905          5183          1980      25482.0
#
#        lat       lng iso2 iso3 Continent_Name
# 0  25.0375  121.5625   TW  TWN           Asia
# 1  35.6870  139.7495   JP  JPN           Asia
# 2  34.6939  135.5022   JP  JPN           Asia
# 3  24.4667   54.3667   AE  ARE           Asia
# 4  25.2631   55.2972   AE  ARE           Asia
# 5  31.2286  121.4747   CN  CHN           Asia
# 6  39.9067  116.3975   CN  CHN           Asia

# %%
# Display Circle Marker on the map

for lat, long, total, radius in zip(cities_continents_visualization_copy['lat'], cities_continents_visualization_copy['lng'], cities_continents_visualization_copy['Smart_Total'], cities_continents_visualization_copy['Smart_Total']):
    folium.CircleMarker(
        location=[lat, long],
        radius = radius / 750,
        fill=True,
        fill_opacity=0.3,
        popup=("Total", total)
    ).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1df29acbc356ad30b0e54eab44f32f0a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1df29acbc356ad30b0e54eab44f32f0a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1df29acbc356ad30b0e54eab44f32f0a = L.map(
#                 &quot;map_1df29acbc356ad30b0e54eab44f32f0a&quot;,
#                 {
#                     center: [29.0, 100.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 3,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0683d1805dacf1d6c12e0856c790ff43 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0683d1805dacf1d6c12e0856c790ff43.addTo(map_1df29acbc356ad30b0e54eab44f32f0a);
#
#
#             tile_layer_0683d1805dacf1d6c12e0856c790ff43.addTo(map_1df29acbc356ad30b0e54eab44f32f0a);
#
#
#             var circle_marker_a28fb60e0485654ff8ba8abea731b950 = L.circleMarker(
#                 [25.0375, 121.5625],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 46.541333333333334, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1df29acbc356ad30b0e54eab44f32f0a);
#
#
#         var popup_bc5e2c4bf323daeabadc76db76120b9c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e5b49b2a3519eac8d7d5de87ee221994 = $(`&lt;div id=&quot;html_e5b49b2a3519eac8d7d5de87ee221994&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Total&#x27;, 34906.0)&lt;/div&gt;`)[0];
#                 popup_bc5e2c4bf323daeabadc76db76120b9c.setContent(html_e5b49b2a3519eac8d7d5de87ee221994);
#
#
#
#         circle_marker_a28fb60e0485654ff8ba8abea731b950.bindPopup(popup_bc5e2c4bf323daeabadc76db76120b9c)
#         ;
#
#
#
#
#             var circle_marker_9cf47c64774aeb9428a018ea3ccf3e15 = L.circleMarker(
#                 [35.687, 139.7495],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 44.076, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1df29acbc356ad30b0e54eab44f32f0a);
#
#
#         var popup_3def4dd5a0fdc117d12a778918de0ede = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9ed994b15afdf9180ef8fe7e0a3e6a35 = $(`&lt;div id=&quot;html_9ed994b15afdf9180ef8fe7e0a3e6a35&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Total&#x27;, 33057.0)&lt;/div&gt;`)[0];
#                 popup_3def4dd5a0fdc117d12a778918de0ede.setContent(html_9ed994b15afdf9180ef8fe7e0a3e6a35);
#
#
#
#         circle_marker_9cf47c64774aeb9428a018ea3ccf3e15.bindPopup(popup_3def4dd5a0fdc117d12a778918de0ede)
#         ;
#
#
#
#
#             var circle_marker_0f3fb97a9c64d21448989f4cd9a18e31 = L.circleMarker(
#                 [34.6939, 135.5022],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 43.40133333333333, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1df29acbc356ad30b0e54eab44f32f0a);
#
#
#         var popup_3c750178b5d53421746b080b7d5ca667 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2e4c944d932c513c632ccfb5ab217e8d = $(`&lt;div id=&quot;html_2e4c944d932c513c632ccfb5ab217e8d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Total&#x27;, 32551.0)&lt;/div&gt;`)[0];
#                 popup_3c750178b5d53421746b080b7d5ca667.setContent(html_2e4c944d932c513c632ccfb5ab217e8d);
#
#
#
#         circle_m

# %%
# FastMarkerCluster

FastMarkerCluster(data=cities_continents_visualization_copy[['lat', 'lng']]).add_to(map)
folium.LayerControl().add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1df29acbc356ad30b0e54eab44f32f0a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1df29acbc356ad30b0e54eab44f32f0a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1df29acbc356ad30b0e54eab44f32f0a = L.map(
#                 &quot;map_1df29acbc356ad30b0e54eab44f32f0a&quot;,
#                 {
#                     center: [29.0, 100.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 3,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0683d1805dacf1d6c12e0856c790ff43 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0683d1805dacf1d6c12e0856c790ff43.addTo(map_1df29acbc356ad30b0e54eab44f32f0a);
#
#
#             tile_layer_0683d1805dacf1d6c12e0856c790ff43.addTo(map_1df29acbc356ad30b0e54eab44f32f0a);
#
#
#             var circle_marker_a28fb60e0485654ff8ba8abea731b950 = L.circleMarker(
#                 [25.0375, 121.5625],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 46.541333333333334, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1df29acbc356ad30b0e54eab44f32f0a);
#
#
#         var popup_bc5e2c4bf323daeabadc76db76120b9c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e5b49b2a3519eac8d7d5de87ee221994 = $(`&lt;div id=&quot;html_e5b49b2a3519eac8d7d5de87ee221994&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Total&#x27;, 34906.0)&lt;/div&gt;`)[0];
#                 popup_bc5e2c4bf323daeabadc76db76120b9c.setContent(html_e5b49b2a3519eac8d7d5de87ee221994);
#
#
#
#         circle_marker_a28fb60e0485654ff8ba8abea731b950.bindPopup(popup_bc5e2c4bf323daeabadc76db76120b9c)
#         ;
#
#
#
#
#             var circle_marker_9cf47c64774aeb9428a018ea3ccf3e15 = L.circleMarker(
#                 [35.687, 139.7495],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 44.076, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1df29acbc356ad30b0e54eab44f32f0a);
#
#
#         var popup_3def4dd5a0fdc117d12a778918de0ede = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9ed994b15afdf9180ef8fe7e0a3e6a35 = $(`&lt;div id=&quot;html_9ed994b15afdf9180ef8fe7e0a3e6a35&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Total&#x27;, 33057.0)&lt;/div&gt;`)[0];
#                 popup_3def4dd5a0fdc117d12a778918de0ede.setContent(html_9ed994b15afdf9180ef8fe7e0a3e6a35);
#
#
#
#         circle_marker_9cf47c64774aeb9428a018ea3ccf3e15.bindPopup(popup_3def4dd5a0fdc117d12a778918de0ede)
#         ;
#
#
#
#
#             var circle_marker_0f3fb97a9c64d21448989f4cd9a18e31 = L.circleMarker(
#                 [34.6939, 135.5022],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 43.40133333333333, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1df29acbc356ad30b0e54eab44f32f0a);
#
#
#         var popup_3c750178b5d53421746b080b7d5ca667 = L.p

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Assuming y_test_logistic and y_pred_logistic are still available from the previous execution
# If not, the models and predictions would need to be re-run.

# Plot Logistic Regression Confusion Matrix with explicit labels
cm_explicit = confusion_matrix(y_test_logistic, y_pred_logistic, labels=[0, 1])
plt.figure(figsize=(6, 5))
sns.heatmap(cm_explicit, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=['Predicted Low', 'Predicted High'],
            yticklabels=['Actual Low', 'Actual High'])
plt.title('Logistic Regression: Confusion Matrix (Explicit Labels)')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Ensure y_test_linear and y_pred_linear are defined from previous model execution
# If you run this cell independently, make sure the linear regression model has been run first.

plt.figure(figsize=(8, 6))
sns.scatterplot(x=y_test_linear, y=y_pred_linear)
plt.plot([y_test_linear.min(), y_test_linear.max()], [y_test_linear.min(), y_test_linear.max()], 'r--')
plt.xlabel("Actual Smart Total")
plt.ylabel("Predicted Smart Total")
plt.title("Linear Regression: Actual vs. Predicted Smart Total")
plt.grid(True)
plt.show()
